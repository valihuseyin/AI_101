# %% [markdown]
# <a href="https://colab.research.google.com/github/valihuseyin/AI_101/blob/main/MathPlot_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # seaborn: statistical data visualization
#
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
# Seaborn is a library for making statistical graphics in Python. It builds on top of matplotlib and integrates closely with pandas data structures.
#
# Seaborn helps you explore and understand your data. Its plotting functions operate on dataframes and arrays containing whole datasets and internally perform the necessary semantic mapping and statistical aggregation to produce informative plots. Its dataset-oriented, declarative API lets you focus on what the different elements of your plots mean, rather than on the details of how to draw them.
#
# https://seaborn.pydata.org/

# %% [markdown]
# https://www.kaggle.com/datasets/uciml/iris
#
# # About Dataset
# The Iris dataset was used in R.A. Fisher's classic 1936 paper, The Use of Multiple Measurements in Taxonomic Problems, and can also be found on the UCI Machine Learning Repository.
#
# It includes three iris species with 50 samples each as well as some properties about each flower. One flower species is linearly separable from the other two, but the other two are not linearly separable from each other.
#
# The columns in this dataset are:
#
# Id
# SepalLengthCm
# SepalWidthCm
# PetalLengthCm
# PetalWidthCm
# Species

# %%
veriler = sns.load_dataset("iris")
veriler
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.lineplot(x="sepal_length", y="sepal_width", data=veriler);
# bu çanak genişliklerine göre türünün tespiti yapılır.

# %%
plt.figure(figsize = (18, 9)),#mathplot değerleri ile seaborn  yönetileiblir. bunlar içiçe çalışır.
sns.lineplot(x=veriler["sepal_length"], y=veriler["sepal_width"])

plt.title('Title  Matplotlib Metodunu kullanıyor ')
plt.show()

# %%
df = pd.read_csv("https://raw.githubusercontent.com/zaferdemirkol/HerkesIcinYapayZeka/main/reklamlar.csv")
df
# Out:
#      Unnamed: 0     TV  radyo  gazete  satışlar     şehir   tür
# 0             0  230.1   37.8    69.2      22.1  İstanbul  Gıda
# 1             1   44.5   39.3    45.1      10.4    Ankara  Gıda
# 2             2   17.2   45.9    69.3       9.3     İzmir  Eşya
# 3             3  151.5   41.3    58.5      18.5     İzmir  Eşya
# 4             4  180.8   10.8    58.4      12.9  İstanbul  Gıda
# ..          ...    ...    ...     ...       ...       ...   ...
# 195         195   38.2    3.7    13.8       7.6  İstanbul  Gıda
# 196         196   94.2    4.9     8.1       9.7  İstanbul  Eşya
# 197         197  177.0    9.3     6.4      12.8  İstanbul  Gıda
# 198         198  283.6   42.0    66.2      25.5  İstanbul  Eşya
# 199         199  232.1    8.6     8.7      13.4    Ankara  Eşya
#
# [200 rows x 7 columns]

# %%
df.drop("Unnamed: 0", axis=1, inplace=True) # Unnamed:0 olanları kaldır. ve tekrar df ata

# %%
df
# Out:
#         TV  radyo  gazete  satışlar     şehir   tür
# 0    230.1   37.8    69.2      22.1  İstanbul  Gıda
# 1     44.5   39.3    45.1      10.4    Ankara  Gıda
# 2     17.2   45.9    69.3       9.3     İzmir  Eşya
# 3    151.5   41.3    58.5      18.5     İzmir  Eşya
# 4    180.8   10.8    58.4      12.9  İstanbul  Gıda
# ..     ...    ...     ...       ...       ...   ...
# 195   38.2    3.7    13.8       7.6  İstanbul  Gıda
# 196   94.2    4.9     8.1       9.7  İstanbul  Eşya
# 197  177.0    9.3     6.4      12.8  İstanbul  Gıda
# 198  283.6   42.0    66.2      25.5  İstanbul  Eşya
# 199  232.1    8.6     8.7      13.4    Ankara  Eşya
#
# [200 rows x 6 columns]

# %%
df.shape[0]
# Out:
# 200

# %%
df.isnull().sum() # nulll olan değerlerin toplam sayıları
# Out:
# TV          0
# radyo       0
# gazete      0
# satışlar    0
# şehir       0
# tür         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   TV        200 non-null    float64
#  1   radyo     200 non-null    float64
#  2   gazete    200 non-null    float64
#  3   satışlar  200 non-null    float64
#  4   şehir     200 non-null    object
#  5   tür       200 non-null    object
# dtypes: float64(4), object(2)
# memory usage: 9.5+ KB

# %%
sns.displot(x = df['TV'], bins=5) # tv nin: dağılım grafiğini verir.
#belirli aralıklarla ne kada rolduklarını gösterir. x:aralık, y :adet
plt.show()

# %%
df['şehir'].value_counts()
# Out:
# şehir
# İstanbul    73
# İzmir       66
# Ankara      61
# Name: count, dtype: int64

# %%
df['şehir'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='şehir'>

# %%
df[df['şehir'] == "İstanbul"]
# Out:
#         TV  radyo  gazete  satışlar     şehir   tür
# 0    230.1   37.8    69.2      22.1  İstanbul  Gıda
# 4    180.8   10.8    58.4      12.9  İstanbul  Gıda
# 10    66.1    5.8    24.2       8.6  İstanbul  Eşya
# 14   204.1   32.9    46.0      19.0  İstanbul  Eşya
# 18    69.2   20.5    18.3      11.3  İstanbul  Gıda
# ..     ...    ...     ...       ...       ...   ...
# 193  166.8   42.0     3.6      19.6  İstanbul  Eşya
# 195   38.2    3.7    13.8       7.6  İstanbul  Gıda
# 196   94.2    4.9     8.1       9.7  İstanbul  Eşya
# 197  177.0    9.3     6.4      12.8  İstanbul  Gıda
# 198  283.6   42.0    66.2      25.5  İstanbul  Eşya
#
# [73 rows x 6 columns]

# %%
pivot_table = df.pivot_table(index='şehir',
                             columns='tür',
                             values='TV',
                             aggfunc='mean')
pivot_table
#katagorik verilere göre hesapalmaan değerlerini gösterebiliriz.
# Out:
# tür             Eşya        Gıda
# şehir
# Ankara    145.196154  162.157143
# İstanbul  144.409375  158.741463
# İzmir     148.078947  114.335714

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df[df['TV']>200]
# Out:
#         TV  radyo  gazete  satışlar     şehir   tür
# 0    230.1   37.8    69.2      22.1  İstanbul  Gıda
# 11   214.7   24.0     4.0      17.4     İzmir  Eşya
# 14   204.1   32.9    46.0      19.0  İstanbul  Eşya
# 17   281.4   39.6    55.8      24.4     İzmir  Eşya
# 20   218.4   27.7    53.4      18.0  İstanbul  Eşya
# ..     ...    ...     ...       ...       ...   ...
# 184  253.8   21.3    30.0      17.6    Ankara  Eşya
# 185  205.0   45.1    19.6      22.6     İzmir  Eşya
# 188  286.0   13.9     3.7      15.9    Ankara  Gıda
# 198  283.6   42.0    66.2      25.5  İstanbul  Eşya
# 199  232.1    8.6     8.7      13.4    Ankara  Eşya
#
# [67 rows x 6 columns]

# %%
sns.jointplot(x = df['TV'], y = df['satışlar'], kind = 'scatter');

# %%
sns.jointplot(x = df['gazete'], y = df['satışlar'], kind = 'reg')
# plot ile scatter ile birleştir.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sns.pairplot(df)
# bütün alanları birbirne göre grafikliyor.

# %%
sns.barplot(x = df['TV'], y = df['şehir'])
# Out:
# <Axes: xlabel='TV', ylabel='şehir'>

# %%
df[df['şehir']=="İstanbul"]["TV"].mean() # ist daki tv satışları mean değeri
# Out:
# np.float64(152.45890410958907)

# %%
sns.catplot(x ="şehir", kind ="count", data = df, hue="tür")

# %%
sns.boxplot(x = df['TV'])
# Out:
# <Axes: xlabel='TV'>

# %%
sns.boxplot(y = df['şehir'], x = df['TV'])
# Out:
# <Axes: xlabel='TV', ylabel='şehir'>

# %%
sns.violinplot( hue = df['şehir'], x = df['TV'], palette="pastel")
plt.legend(loc=2)

# %%
sns.stripplot(x=df['şehir'], y=df['TV'], palette="deep", hue=df['tür'])
# Out:
# <Axes: xlabel='şehir', ylabel='TV'>

# %%
sns.swarmplot(x=df['şehir'], y=df['TV'], palette="deep", hue=df['tür'])
# Out:
# <Axes: xlabel='şehir', ylabel='TV'>

# %%
sns.FacetGrid(df, col = 'şehir', row = 'tür').map(sns.histplot, 'TV')

# %%
sns.lmplot(x = 'TV', y = 'satışlar', data = df, hue="şehir") #regresyon grafiği
