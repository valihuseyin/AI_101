# %% [markdown]
# <a href="https://colab.research.google.com/github/valihuseyin/AI_101/blob/main/Pandas_Intro_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("client_list.xlxs",
                            sheet_name="client_list",
                            usecols=['first_name', 'Age', 'gender'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-771247384.py in <cell line: 0>()
# ----> 1 df=pd.read_excel("client_list.xlxs",
#       2                             sheet_name="client_list",
#       3                             usecols=['first_name', 'Age', 'gender'])
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
df

# %%
df['c4'] = np.nan

# %%
# verileri düzenleme
df = pd.DataFrame(np.arange(0, 15).reshape(5, 3),
                                    index=['a', 'b', 'c', 'd', 'e'],
                                    columns=['c1', 'c2', 'c3'])

# %%
df
# Out:
#    c1  c2  c3
# a   0   1   2
# b   3   4   5
# c   6   7   8
# d   9  10  11
# e  12  13  14

# %%
df.isnull()# nulll verileri1 ve ya 0 oalrak gösterir

# %%
df.isnull().sum()

# %%
df.info()

# %%
# kolon ekleme, Nan değerinde
df['c4'] = np.nan

# %%
df

# %%
df.loc['f'] = np.arange(15, 19) # f kolonu ekle değerleri 15 den başla ,19 a kadar değer ata

# %%
df

# %%
df.loc['g'] = np.nan

# %%
df

# %%
#değer atama
df['c4']['a'] = 20
df

# %%
df

# %%
df.isnull()

# %%
df.isnull().sum()

# %%
df.isnull().sum().sum()

# %%
df.dropna()

# %%
df.dropna(how='all', axis=0)
# Out:
#    c1  c2  c3
# a   0   1   2
# b   3   4   5
# c   6   7   8
# d   9  10  11
# e  12  13  14

# %%
df2 = df.copy()

# %%
df2

# %%
filled = df.fillna(0) # nan ları doldur.
filled
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2082211769.py in <cell line: 0>()
# ----> 1 filled = df.fillna(0) # nan ları doldur.
#       2 filled
#
# NameError: name 'df' is not defined

# %%
df.mean()
# Out:
# c1    6.0
# c2    7.0
# c3    8.0
# dtype: float64

# %%
df.fillna(df.mean())
# Out:
#    c1  c2  c3
# a   0   1   2
# b   3   4   5
# c   6   7   8
# d   9  10  11
# e  12  13  14

# %%
data = {
        'Kategori': ['Elektronik', 'Giyim', 'Giyim', 'Elektronik', 'Elektronik', 'Giyim'],
            'Marka': ['Samsung', 'Nike', 'Adidas', 'Apple', 'Sony', 'Levis'],
            'Fiyat': [2000, 300, 250, 5000, 1500, 150]

}

# %%
df = pd.DataFrame(data)
df
# Out:
#      Kategori    Marka  Fiyat
# 0  Elektronik  Samsung   2000
# 1       Giyim     Nike    300
# 2       Giyim   Adidas    250
# 3  Elektronik    Apple   5000
# 4  Elektronik     Sony   1500
# 5       Giyim    Levis    150

# %%
sensor_data = pd.read_csv("sensor.csv")
sensor_data

# %%
df.mean()

# %%
sensor_data = pd.read_csv("mnist_test.csv")
sensor_data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4208689260.py in <cell line: 0>()
# ----> 1 sensor_data = pd.read_csv("mnist_test.csv")
#       2 sensor_data
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df
# Out:
#      Kategori    Marka  Fiyat
# 0  Elektronik  Samsung   2000
# 1       Giyim     Nike    300
# 2       Giyim   Adidas    250
# 3  Elektronik    Apple   5000
# 4  Elektronik     Sony   1500
# 5       Giyim    Levis    150

# %%
df.fillna(df.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-634187881.py in <cell line: 0>()
# ----> 1 df.fillna(df.mean())
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
#   11695             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# ...

# %%
df.fillna(method="ffill")
# Out:
# /tmp/ipython-input-3944122520.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill")
#      Kategori    Marka  Fiyat
# 0  Elektronik  Samsung   2000
# 1       Giyim     Nike    300
# 2       Giyim   Adidas    250
# 3  Elektronik    Apple   5000
# 4  Elektronik     Sony   1500
# 5       Giyim    Levis    150

# %%
df.fillna(method="bfill")
# Out:
# /tmp/ipython-input-3896554658.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="bfill")
#      Kategori    Marka  Fiyat
# 0  Elektronik  Samsung   2000
# 1       Giyim     Nike    300
# 2       Giyim   Adidas    250
# 3  Elektronik    Apple   5000
# 4  Elektronik     Sony   1500
# 5       Giyim    Levis    150

# %%
data = {
        'Kategori': ['Elektronik', 'Giyim', 'Giyim', 'Elektronik', 'Elektronik', 'Giyim'],
            'Marka': ['Samsung', 'Nike', 'Adidas', 'Apple', 'Sony', 'Levis'],
            'Fiyat': [2000, 300, 250, 5000, 1500, 150]

}

# %%
df = pd.DataFrame(data)
df
# Out:
#      Kategori    Marka  Fiyat
# 0  Elektronik  Samsung   2000
# 1       Giyim     Nike    300
# 2       Giyim   Adidas    250
# 3  Elektronik    Apple   5000
# 4  Elektronik     Sony   1500
# 5       Giyim    Levis    150

# %%
grouped = df.groupby('Kategori').agg({'Fiyat': ['mean', 'min', 'max']})
print(grouped)
# Out:
#                   Fiyat
#                    mean   min   max
# Kategori
# Elektronik  2833.333333  1500  5000
# Giyim        233.333333   150   300
