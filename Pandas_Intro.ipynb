# %% [markdown]
# <a href="https://colab.research.google.com/github/valihuseyin/AI_101/blob/main/Pandas_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PANDAS
# Yapılandırılmış veri üzerinde çalışır.Yapılandırmış veri yani bir sistematiği olan verilerdir. Hep istikrar vardır.
#  Excelin python halidir diyebiliriz. Veri tabanı işlemlerini yaptığımız yer gibi düşün.

# %%
import pandas as pd
import numpy as np

# %%
isimler = ["Hüseyin","Zehra","Alihan","fatma betül","Hatice kübra"]
yaslar =[37,34,10,5,1]
soyIsimler =["Karadağ","Ersen","Karadağ","Karadağ","Karadağ"]
veri = {"isim":isimler,"yas":yaslar,"soyisim":soyIsimler}

# %%
type(veri)
# Out:
# dict

# %%
ogrenci = pd.DataFrame(veri)#verilen dic  yapısnı bir dataFrame yap

# %%
ogrenci
# Out:
#            isim  yas  soyisim
# 0       Hüseyin   37  Karadağ
# 1         Zehra   34    Ersen
# 2        Alihan   10  Karadağ
# 3   fatma betül    5  Karadağ
# 4  Hatice kübra    1  Karadağ

# %%
ogrenci.head(1)
# Out:
#       isim  yas  soyisim
# 0  Hüseyin   37  Karadağ

# %%
veri = [['zafer', 'demirkol', 43],
                ['ege', 'genç', 23],
                ['ayşegül', 'görgülü', 78],
                ['tamer', 'bahadır', 56],
                ['cemile', 'aslan', 26],
                ['kemal', 'yılmaz', 14],
                ['gönül', 'eker', 46],
                ['seyhan', 'deviren', 92],
]

# %%
veri
# Out:
# [['zafer', 'demirkol', 43],
#  ['ege', 'genç', 23],
#  ['ayşegül', 'görgülü', 78],
#  ['tamer', 'bahadır', 56],
#  ['cemile', 'aslan', 26],
#  ['kemal', 'yılmaz', 14],
#  ['gönül', 'eker', 46],
#  ['seyhan', 'deviren', 92]]

# %%
df = pd.DataFrame(veri,columns=["isim","soyisim","yas"])# sütünlara isim vermek

# %%
df
# Out:
#       isim   soyisim  yas
# 0    zafer  demirkol   43
# 1      ege      genç   23
# 2  ayşegül   görgülü   78
# 3    tamer   bahadır   56
# 4   cemile     aslan   26
# 5    kemal    yılmaz   14
# 6    gönül      eker   46
# 7   seyhan   deviren   92

# %%
df2 = pd.DataFrame(np.arange(16).reshape((4, 4)),
                     index=['kırmızı', 'mavi', 'sarı', 'beyaz'],
                     columns=['top', 'kalem', 'kağıt', 'fincan']) #4x4 16 kadar seri sayıları üret. index- (satır) ve sütün isimlerini verir
df2
# Out:
#          top  kalem  kağıt  fincan
# kırmızı    0      1      2       3
# mavi       4      5      6       7
# sarı       8      9     10      11
# beyaz     12     13     14      15

# %%
df2["top"]
# Out:
# kırmızı     0
# mavi        4
# sarı        8
# beyaz      12
# Name: top, dtype: int64

# %%
df2[["top","kalem"]]
# Out:
#          top  kalem
# kırmızı    0      1
# mavi       4      5
# sarı       8      9
# beyaz     12     13

# %%
df2["kalem"][0:2]# kalem sütünun  belirtilen satır aralığını getirir. 1 ve 1. satırlar gelir
# Out:
# kırmızı    1
# mavi       5
# Name: kalem, dtype: int64

# %%
df2["kalem"][["mavi","beyaz"]]#bir sütüna ait olan index leri getirir
# Out:
# mavi      5
# beyaz    13
# Name: kalem, dtype: int64

# %%
df2.iloc[1:3]#[index:cloumns] --> iloc: index bazlı işleme yaptırır.iloc: index location
# Out:
#       top  kalem  kağıt  fincan
# mavi    4      5      6       7
# sarı    8      9     10      11

# %%
df2.loc["kırmızı":"sarı"] # kırmızı ve sarı sütünları aralığını
# Out:
#          top  kalem  kağıt  fincan
# kırmızı    0      1      2       3
# mavi       4      5      6       7
# sarı       8      9     10      11

# %%
df2.loc["kırmızı":"sarı", "kalem":"fincan"]
# Out:
#          kalem  kağıt  fincan
# kırmızı      1      2       3
# mavi         5      6       7
# sarı         9     10      11

# %%
#loc ifadesi de location anlamına gelir.kolon ve index etikeleryle işlem yapar.
df2.loc[['kırmızı', 'beyaz']]
# Out:
#          top  kalem  kağıt  fincan
# kırmızı    0      1      2       3
# beyaz     12     13     14      15

# %%
data = pd.read_table("http://bit.ly/chiporders")

# %%
data.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
data.tail(5)
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
izleyiciler = pd.read_table("http://bit.ly/movieusers")
izleyiciler
# Out:
#           1|24|M|technician|85711
# 0              2|53|F|other|94043
# 1             3|23|M|writer|32067
# 2         4|24|M|technician|43537
# 3              5|33|F|other|15213
# 4          6|42|M|executive|98101
# ..                            ...
# 937        939|26|F|student|33319
# 938  940|32|M|administrator|02215
# 939        941|20|M|student|97229
# 940      942|48|F|librarian|78209
# 941        943|22|M|student|77841
#
# [942 rows x 1 columns]

# %%
sutunlar = ["id", "yas", "cinsiyet", "meslek", "zip_code"]
izl = pd.read_table("http://bit.ly/movieusers", sep="|",  names=sutunlar)
izl
# Out:
#       id  yas cinsiyet         meslek zip_code
# 0      1   24        M     technician    85711
# 1      2   53        F          other    94043
# 2      3   23        M         writer    32067
# 3      4   24        M     technician    43537
# 4      5   33        F          other    15213
# ..   ...  ...      ...            ...      ...
# 938  939   26        F        student    33319
# 939  940   32        M  administrator    02215
# 940  941   20        M        student    97229
# 941  942   48        F      librarian    78209
# 942  943   22        M        student    77841
#
# [943 rows x 5 columns]

# %%
ufo = pd.read_csv("http://bit.ly/uforeports")
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo.describe().T #sayısal alanları açıklanmasında yardımcı olur, istatiksel bilgiler verir. (.T transporm satır ve sütünları ters cevirir.)
# Out:
#                  count unique               top  freq
# City             18215   6475           Seattle   187
# Colors Reported   2882     27               RED   780
# Shape Reported   15597     27             LIGHT  2803
# State            18241     52                CA  2529
# Time             18241  16145  11/16/1999 19:00    27

# %%
ufo["City"]
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
#                  ...
# 18236              Grant Park
# 18237             Spirit Lake
# 18238             Eagle River
# 18239             Eagle River
# 18240                    Ybor
# Name: City, Length: 18241, dtype: object

# %%
ufo.describe()
# Out:
#            City Colors Reported Shape Reported  State              Time
# count     18215            2882          15597  18241             18241
# unique     6475              27             27     52             16145
# top     Seattle             RED          LIGHT     CA  11/16/1999 19:00
# freq        187             780           2803   2529                27

# %%
ufo.iloc[1:4, 2:]
# Out:
#   Shape Reported State             Time
# 1          OTHER    NJ  6/30/1930 20:00
# 2           OVAL    CO  2/15/1931 14:00
# 3           DISK    KS   6/1/1931 13:00

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo.columns = ufo.columns.str.replace(' ', '_') # başlıkda yer alan boşlukları _ ile replace eder.

# %%
ufo.columns
# Out:
# Index(['City', 'Colors_Reported', 'Shape_Reported', 'State', 'Time'], dtype='object')

# %%
movies = pd.read_csv("http://bit.ly/imdbratings")
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies.sort_values("title", ascending=False)# sıralama title a göre
# Out:
#      star_rating                  title content_rating      genre  duration  \
# 864          7.5                  [Rec]              R     Horror        78
# 526          7.8                   Zulu        UNRATED      Drama       138
# 615          7.7             Zombieland              R     Comedy        88
# 677          7.7                 Zodiac              R      Crime       157
# 955          7.4       Zero Dark Thirty              R      Drama       157
# ..           ...                    ...            ...        ...       ...
# 110          8.3  2001: A Space Odyssey              G    Mystery       160
# 698          7.6              127 Hours              R  Adventure        94
# 201          8.1       12 Years a Slave              R  Biography       134
# 5            8.9           12 Angry Men      NOT RATED      Drama        96
# 542          7.8   (500) Days of Summer          PG-13     Comedy        95
#
#                                            actors_list
# ...

# %%
# şaertlı veri okuma
movies[movies.duration >= 200] #200 üzeri süresi olanlar
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
movies[(movies.duration >= 200) & (movies.genre=="Drama")]# 200 dk olan ve drama olan
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
